# %%
#Inintalization()
# original state_0&_1
#lam = 0.1
# 100 epochs
# !python3 fedavg_vs_ibcs_cifar.py
# Out:
# States are:
#  [0.9449, 0.0087, 0.9913]
#  [0.0551, 0.8509, 0.1491]
#  K=  20
#  Lambda=  0.1
# This is the last fix
# No GPU found
#
#
# Files already downloaded and verified
# Files already downloaded and verified
# Round   0 fedavg, Accuracy 10.000, Loss 2.303, Accum Power: 61.000
# Round   0 ibcs, Accuracy 10.090, Loss 2.304, Accum Power: 61.000
# Round   1 fedavg, Accuracy 9.970, Loss 2.300, Accum Power: 128.000
# Round   1 ibcs, Accuracy 10.370, Loss 2.303, Accum Power: 121.000
# Round   2 fedavg, Accuracy 10.390, Loss 2.297, Accum Power: 128.000
# Round   2 ibcs, Accuracy 11.430, Loss 2.302, Accum Power: 121.000
# Round   3 fedavg, Accuracy 14.530, Loss 2.293, Accum Power: 128.000
# Round   3 ibcs, Accuracy 12.240, Loss 2.301, Accum Power: 121.000
# Round   4 fedavg, Accuracy 15.660, Loss 2.285, Accum Power: 128.000
# Round   4 ibcs, Accuracy 13.270, Loss 2.299, Accum Power: 121.000
# Round   5 fedavg, Accuracy 16.270, Loss 2.271, Accum Power: 128.000
# ...

# %%
import csv
import matplotlib.pyplot as plt
top_k = 20
lam = 0.1

def convert_strings_to_floats(input_array):
    output_array = []
    for element in input_array:
        converted_float = float(element)
        output_array.append(converted_float)
    return output_array


fedavg_acc = []
ibcs_acc = []

fedavg_loss = []
ibcs_loss = []

fedavg_power = []
ibcs_power = []
f = open(f'./cifar_results/fedavg_acc_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    fedavg_acc.append(line.strip())
fedavg_acc = convert_strings_to_floats(fedavg_acc)

f = open(f'./cifar_results/fedavg_loss_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    fedavg_loss.append(line.strip())
fedavg_loss = convert_strings_to_floats(fedavg_loss)

f = open(f'./cifar_results/fedavg_power_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    fedavg_power.append(line.strip())
fedavg_power = convert_strings_to_floats(fedavg_power)

f = open(f'./cifar_results/ibcs_acc_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    ibcs_acc.append(line.strip())
ibcs_acc = convert_strings_to_floats(ibcs_acc)

f = open(f'./cifar_results/ibcs_loss_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    ibcs_loss.append(line.strip())
ibcs_loss = convert_strings_to_floats(ibcs_loss)

f = open(f'./cifar_results/ibcs_power_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    ibcs_power.append(line.strip())
ibcs_power = convert_strings_to_floats(ibcs_power)

fig, ax = plt.subplots()
ax.plot(fedavg_acc)
ax.plot(ibcs_acc)

ax.set_title('Accuracy')
ax.legend(['FedAvg', 'IBCS'])
ax.xaxis.set_label_text('Gobal Epochs')
ax.yaxis.set_label_text('Accuracy in %')
plt.savefig(f'./cifar_results/acc_lam{lam}_k_{top_k}.png')
plt.show()


fig, ax = plt.subplots()
ax.plot(fedavg_loss)
ax.plot(ibcs_loss)

ax.set_title('Loss')
ax.legend(['FedAvg', 'IBCS'])
ax.xaxis.set_label_text('Gobal Epochs')
ax.yaxis.set_label_text('Loss')
plt.savefig(f'./cifar_results/loss_lam{lam}_k_{top_k}.png')
plt.show()


fig, ax = plt.subplots()
ax.plot(fedavg_power)
ax.plot(ibcs_power)

ax.set_title('Power')
ax.legend(['FedAvg', 'IBCS'])
ax.xaxis.set_label_text('Gobal Epochs')
ax.yaxis.set_label_text('Power')
plt.savefig(f'./cifar_results/power_lam{lam}_k_{top_k}.png')
plt.show()

# %%
#Inintalization()
# original state_0&_1
#lam = 0.1
# 100 global epochs
# latest changes (Aug, 19 2023 at 4:57 pm)
# !python3 fedavg_vs_ibcs_cifar.py
# Out:
# States are:
#  [0.9449, 0.0087, 0.9913]
#  [0.0551, 0.8509, 0.1491]
#  K=  20
#  Lambda=  0.1
# No GPU found
#
#
# dataset is cifar
# Files already downloaded and verified
# Files already downloaded and verified
# Numper of global epochs = 100
# Round   0 fedavg, Accuracy 10.000, Loss 2.303, Accum Power: 67.000
# Round   0 ibcs, Accuracy 9.370, Loss 2.303, Accum Power: 0.000
# Round   1 fedavg, Accuracy 10.000, Loss 2.302, Accum Power: 208.000
# Round   1 ibcs, Accuracy 9.760, Loss 2.302, Accum Power: 0.000
# Round   2 fedavg, Accuracy 10.000, Loss 2.301, Accum Power: 208.000
# Round   2 ibcs, Accuracy 10.150, Loss 2.301, Accum Power: 0.000
# Round   3 fedavg, Accuracy 10.010, Loss 2.300, Accum Power: 277.000
# Round   3 ibcs, Accuracy 10.190, Loss 2.300, Accum Power: 0.000
# Round   4 fedavg, Accuracy 10.090, Loss 2.299, Accum Power: 346.000
# Round   4 ibcs, Accuracy 10.490, Loss 2.299, Accum Power: 0.000
# Round   5 fedavg, Accuracy 10.210, Loss 2.298, Accum Power: 346.000
# ...

# %%
import csv
import matplotlib.pyplot as plt
top_k = 20
lam = 0.1

def convert_strings_to_floats(input_array):
    output_array = []
    for element in input_array:
        converted_float = float(element)
        output_array.append(converted_float)
    return output_array


fedavg_acc = []
ibcs_acc = []

fedavg_loss = []
ibcs_loss = []

fedavg_power = []
ibcs_power = []
f = open(f'./cifar_results/fedavg_acc_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    fedavg_acc.append(line.strip())
fedavg_acc = convert_strings_to_floats(fedavg_acc)

f = open(f'./cifar_results/fedavg_loss_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    fedavg_loss.append(line.strip())
fedavg_loss = convert_strings_to_floats(fedavg_loss)

f = open(f'./cifar_results/fedavg_power_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    fedavg_power.append(line.strip())
fedavg_power = convert_strings_to_floats(fedavg_power)

f = open(f'./cifar_results/ibcs_acc_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    ibcs_acc.append(line.strip())
ibcs_acc = convert_strings_to_floats(ibcs_acc)

f = open(f'./cifar_results/ibcs_loss_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    ibcs_loss.append(line.strip())
ibcs_loss = convert_strings_to_floats(ibcs_loss)

f = open(f'./cifar_results/ibcs_power_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    ibcs_power.append(line.strip())
ibcs_power = convert_strings_to_floats(ibcs_power)

fig, ax = plt.subplots()
ax.plot(fedavg_acc)
ax.plot(ibcs_acc)

ax.set_title('Accuracy')
ax.legend(['FedAvg', 'IBCS'])
ax.xaxis.set_label_text('Gobal Epochs')
ax.yaxis.set_label_text('Accuracy in %')
plt.savefig(f'./cifar_results/acc_lam{lam}_k_{top_k}.png')
plt.show()


fig, ax = plt.subplots()
ax.plot(fedavg_loss)
ax.plot(ibcs_loss)

ax.set_title('Loss')
ax.legend(['FedAvg', 'IBCS'])
ax.xaxis.set_label_text('Gobal Epochs')
ax.yaxis.set_label_text('Loss')
plt.savefig(f'./cifar_results/loss_lam{lam}_k_{top_k}.png')
plt.show()


fig, ax = plt.subplots()
ax.plot(fedavg_power)
ax.plot(ibcs_power)

ax.set_title('Power')
ax.legend(['FedAvg', 'IBCS'])
ax.xaxis.set_label_text('Gobal Epochs')
ax.yaxis.set_label_text('Power')
plt.savefig(f'./cifar_results/power_lam{lam}_k_{top_k}.png')
plt.show()

# %%
#Inintalization()
# original state_0&_1
#lam = 0.1
# 100 global epochs
# latest changes (Aug, 19 2023 at 5:56 pm)
# !python3 fedavg_vs_ibcs_cifar.py
# Out:
# States are:
#  [0.9449, 0.0087, 0.9913]
#  [0.0551, 0.8509, 0.1491]
#  K=  20
#  Lambda=  0.1
# No GPU found
#
#
# dataset is cifar
# Files already downloaded and verified
# Files already downloaded and verified
# Numper of global epochs = 1000
# Round   0 fedavg, Accuracy 9.460, Loss 2.304, Accum Power: 135.000
# Round   0 ibcs, Accuracy 11.670, Loss 2.302, Accum Power: 0.000
# Round   1 fedavg, Accuracy 10.050, Loss 2.303, Accum Power: 135.000
# Round   1 ibcs, Accuracy 12.300, Loss 2.301, Accum Power: 0.000
# Round   2 fedavg, Accuracy 10.610, Loss 2.302, Accum Power: 211.000
# Round   2 ibcs, Accuracy 12.750, Loss 2.299, Accum Power: 0.000
# Round   3 fedavg, Accuracy 12.730, Loss 2.300, Accum Power: 211.000
# Round   3 ibcs, Accuracy 13.230, Loss 2.296, Accum Power: 63.000
# Round   4 fedavg, Accuracy 14.060, Loss 2.298, Accum Power: 355.000
# Round   4 ibcs, Accuracy 14.200, Loss 2.291, Accum Power: 63.000
# Round   5 fedavg, Accuracy 15.040, Loss 2.296, Accum Power: 355.000
# ...

# %%
import csv
import matplotlib.pyplot as plt
top_k = 20
lam = 0.1

def convert_strings_to_floats(input_array):
    output_array = []
    for element in input_array:
        converted_float = float(element)
        output_array.append(converted_float)
    return output_array


fedavg_acc = []
ibcs_acc = []

fedavg_loss = []
ibcs_loss = []

fedavg_power = []
ibcs_power = []
f = open(f'./cifar_results/fedavg_acc_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    fedavg_acc.append(line.strip())
fedavg_acc = convert_strings_to_floats(fedavg_acc)

f = open(f'./cifar_results/fedavg_loss_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    fedavg_loss.append(line.strip())
fedavg_loss = convert_strings_to_floats(fedavg_loss)

f = open(f'./cifar_results/fedavg_power_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    fedavg_power.append(line.strip())
fedavg_power = convert_strings_to_floats(fedavg_power)

f = open(f'./cifar_results/ibcs_acc_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    ibcs_acc.append(line.strip())
ibcs_acc = convert_strings_to_floats(ibcs_acc)

f = open(f'./cifar_results/ibcs_loss_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    ibcs_loss.append(line.strip())
ibcs_loss = convert_strings_to_floats(ibcs_loss)

f = open(f'./cifar_results/ibcs_power_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    ibcs_power.append(line.strip())
ibcs_power = convert_strings_to_floats(ibcs_power)

fig, ax = plt.subplots()
ax.plot(fedavg_acc)
ax.plot(ibcs_acc)

ax.set_title('Accuracy')
ax.legend(['FedAvg', 'IBCS'])
ax.xaxis.set_label_text('Gobal Epochs')
ax.yaxis.set_label_text('Accuracy in %')
plt.savefig(f'./cifar_results/acc_lam{lam}_k_{top_k}.png')
plt.show()


fig, ax = plt.subplots()
ax.plot(fedavg_loss)
ax.plot(ibcs_loss)

ax.set_title('Loss')
ax.legend(['FedAvg', 'IBCS'])
ax.xaxis.set_label_text('Gobal Epochs')
ax.yaxis.set_label_text('Loss')
plt.savefig(f'./cifar_results/loss_lam{lam}_k_{top_k}.png')
plt.show()


fig, ax = plt.subplots()
ax.plot(fedavg_power)
ax.plot(ibcs_power)

ax.set_title('Power')
ax.legend(['FedAvg', 'IBCS'])
ax.xaxis.set_label_text('Gobal Epochs')
ax.yaxis.set_label_text('Power')
plt.savefig(f'./cifar_results/power_lam{lam}_k_{top_k}.png')
plt.show()

# %%
#Inintalization()
# original state_0&_1
#lam = 0.1
# 100 global epochs
# 3 local epochs instead of 10
# Three algorithms (FedAvg, ibcs, pp)
# latest changes (Aug, 21 2023 at 6:10 pm)
# !python3 fedavg_vs_ibcs_cifar.py
# Out:
# States are:
#  [0.9449, 0.0087, 0.9913]
#  [0.0551, 0.8509, 0.1491]
#  K=  20
#  Lambda=  0.1
# No GPU found
#
#
# Files already downloaded and verified
# Files already downloaded and verified
# Numper of global epochs = 100
# Round   0 fedavg, Accuracy 9.130, Loss 2.303, Accum Power: 66.000
# Round   0 ibcs, Accuracy 10.000, Loss 2.302, Accum Power: 62.000
# Round   0 pp, Accuracy 10.000, Loss 2.305, Accum Power: 74.000
# Round   1 fedavg, Accuracy 8.860, Loss 2.302, Accum Power: 208.000
# Round   1 ibcs, Accuracy 10.500, Loss 2.299, Accum Power: 62.000
# Round   1 pp, Accuracy 10.000, Loss 2.304, Accum Power: 74.000
# Round   2 fedavg, Accuracy 9.030, Loss 2.302, Accum Power: 270.000
# Round   2 ibcs, Accuracy 14.560, Loss 2.296, Accum Power: 62.000
# Round   2 pp, Accuracy 9.990, Loss 2.304, Accum Power: 74.000
# Round   3 fedavg, Accuracy 9.780, Loss 2.301, Accum Power: 270.000
# Round   3 ibcs, Accuracy 18.500, Loss 2.291, Accum Power: 62.000
# ...

# %%
import csv
import matplotlib.pyplot as plt
top_k = 20
lam = 0.1

def convert_strings_to_floats(input_array):
    output_array = []
    for element in input_array:
        converted_float = float(element)
        output_array.append(converted_float)
    return output_array


fedavg_acc = []
ibcs_acc = []
pp_acc = []

fedavg_loss = []
ibcs_loss = []
pp_loss = []

fedavg_power = []
ibcs_power = []
pp_power = []


f = open(f'./cifar_results/fedavg_acc_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    fedavg_acc.append(line.strip())
fedavg_acc = convert_strings_to_floats(fedavg_acc)

f = open(f'./cifar_results/fedavg_loss_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    fedavg_loss.append(line.strip())
fedavg_loss = convert_strings_to_floats(fedavg_loss)

f = open(f'./cifar_results/fedavg_power_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    fedavg_power.append(line.strip())
fedavg_power = convert_strings_to_floats(fedavg_power)

f = open(f'./cifar_results/ibcs_acc_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    ibcs_acc.append(line.strip())
ibcs_acc = convert_strings_to_floats(ibcs_acc)

f = open(f'./cifar_results/ibcs_loss_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    ibcs_loss.append(line.strip())
ibcs_loss = convert_strings_to_floats(ibcs_loss)

f = open(f'./cifar_results/ibcs_power_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    ibcs_power.append(line.strip())
ibcs_power = convert_strings_to_floats(ibcs_power)

f = open(f'./cifar_results/pp_acc_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    pp_acc.append(line.strip())
pp_acc = convert_strings_to_floats(pp_acc)

f = open(f'./cifar_results/pp_loss_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    pp_loss.append(line.strip())
pp_loss = convert_strings_to_floats(pp_loss)

f = open(f'./cifar_results/pp_power_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    pp_power.append(line.strip())
pp_power = convert_strings_to_floats(pp_power)

fig, ax = plt.subplots()
ax.plot(fedavg_acc)
ax.plot(ibcs_acc)
ax.plot(pp_acc)

ax.set_title('Accuracy')
ax.legend(['FedAvg', 'IBCS', 'PP'])
ax.xaxis.set_label_text('Gobal Epochs')
ax.yaxis.set_label_text('Accuracy in %')
plt.savefig(f'./cifar_results/acc_lam{lam}_k_{top_k}.png')
plt.show()


fig, ax = plt.subplots()
ax.plot(fedavg_loss)
ax.plot(ibcs_loss)
ax.plot(pp_loss)

ax.set_title('Loss')
ax.legend(['FedAvg', 'IBCS', 'PP'])
ax.xaxis.set_label_text('Gobal Epochs')
ax.yaxis.set_label_text('Loss')
plt.savefig(f'./cifar_results/loss_lam{lam}_k_{top_k}.png')
plt.show()


fig, ax = plt.subplots()
ax.plot(fedavg_power)
ax.plot(ibcs_power)
ax.plot(pp_power)

ax.set_title('Power')
ax.legend(['FedAvg', 'IBCS', 'PP'])
ax.xaxis.set_label_text('Gobal Epochs')
ax.yaxis.set_label_text('Power')
plt.savefig(f'./cifar_results/power_lam{lam}_k_{top_k}.png')
plt.show()

# %%
#Inintalization()
# original state_0&_1
#lam = 0.1
# 1000 global epochs
# 10 local epoch
# 32 batch size
# Three algorithms (FedAvg, ibcs, pp)
# latest changes (Aug, 21 2023 at 9:06 pm)
# !python3 fedavg_vs_ibcs_cifar.py
# Out:
# States are:
#  [0.9449, 0.0087, 0.9913]
#  [0.0551, 0.8509, 0.1491]
#  K=  20
#  Lambda=  0.1
# No GPU found
#
#
# Files already downloaded and verified
# Files already downloaded and verified
# Numper of global epochs = 1000
# Number of local epochs = 10
# Batch size = 32
# Round   0 fedavg, Accuracy 11.730, Loss 2.300, Accum Power: 139.000
# Round   0 ibcs, Accuracy 12.170, Loss 2.302, Accum Power: 0.000
# Round   0 pp, Accuracy 12.700, Loss 2.299, Accum Power: 0.000
# Round   1 fedavg, Accuracy 14.140, Loss 2.290, Accum Power: 212.000
# Round   1 ibcs, Accuracy 12.720, Loss 2.297, Accum Power: 0.000
# Round   1 pp, Accuracy 14.840, Loss 2.289, Accum Power: 0.000
# Round   2 fedavg, Accuracy 19.100, Loss 2.235, Accum Power: 426.000
# Round   2 ibcs, Accuracy 15.730, Loss 2.283, Accum Power: 0.000
# Round   2 pp, Accuracy 19.230, Loss 2.220, Accum Power: 0.000
# Round   3 fedavg, Accuracy 23.670, Loss 2.133, Accum Power: 628.000
# ...

# %%
import csv
import matplotlib.pyplot as plt
top_k = 20
lam = 0.1

def convert_strings_to_floats(input_array):
    output_array = []
    for element in input_array:
        converted_float = float(element)
        output_array.append(converted_float)
    return output_array


fedavg_acc = []
ibcs_acc = []
pp_acc = []

fedavg_loss = []
ibcs_loss = []
pp_loss = []

fedavg_power = []
ibcs_power = []
pp_power = []


f = open(f'./cifar_results/fedavg_acc_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    fedavg_acc.append(line.strip())
fedavg_acc = convert_strings_to_floats(fedavg_acc)

f = open(f'./cifar_results/fedavg_loss_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    fedavg_loss.append(line.strip())
fedavg_loss = convert_strings_to_floats(fedavg_loss)

f = open(f'./cifar_results/fedavg_power_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    fedavg_power.append(line.strip())
fedavg_power = convert_strings_to_floats(fedavg_power)

f = open(f'./cifar_results/ibcs_acc_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    ibcs_acc.append(line.strip())
ibcs_acc = convert_strings_to_floats(ibcs_acc)

f = open(f'./cifar_results/ibcs_loss_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    ibcs_loss.append(line.strip())
ibcs_loss = convert_strings_to_floats(ibcs_loss)

f = open(f'./cifar_results/ibcs_power_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    ibcs_power.append(line.strip())
ibcs_power = convert_strings_to_floats(ibcs_power)

f = open(f'./cifar_results/pp_acc_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    pp_acc.append(line.strip())
pp_acc = convert_strings_to_floats(pp_acc)

f = open(f'./cifar_results/pp_loss_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    pp_loss.append(line.strip())
pp_loss = convert_strings_to_floats(pp_loss)

f = open(f'./cifar_results/pp_power_lam_{lam}_k_{top_k}.txt', 'r')
for line in f:
    pp_power.append(line.strip())
pp_power = convert_strings_to_floats(pp_power)

fig, ax = plt.subplots()
ax.plot(fedavg_acc)
ax.plot(ibcs_acc)
ax.plot(pp_acc)

ax.set_title('Accuracy')
ax.legend(['FedAvg', 'IBCS', 'PP'])
ax.xaxis.set_label_text('Gobal Epochs')
ax.yaxis.set_label_text('Accuracy in %')
plt.savefig(f'./cifar_results/acc_lam{lam}_k_{top_k}.png')
plt.show()


fig, ax = plt.subplots()
ax.plot(fedavg_loss)
ax.plot(ibcs_loss)
ax.plot(pp_loss)

ax.set_title('Loss')
ax.legend(['FedAvg', 'IBCS', 'PP'])
ax.xaxis.set_label_text('Gobal Epochs')
ax.yaxis.set_label_text('Loss')
plt.savefig(f'./cifar_results/loss_lam{lam}_k_{top_k}.png')
plt.show()


fig, ax = plt.subplots()
ax.plot(fedavg_power)
ax.plot(ibcs_power)
ax.plot(pp_power)

ax.set_title('Power')
ax.legend(['FedAvg', 'IBCS', 'PP'])
ax.xaxis.set_label_text('Gobal Epochs')
ax.yaxis.set_label_text('Power')
plt.savefig(f'./cifar_results/power_lam{lam}_k_{top_k}.png')
plt.show()
